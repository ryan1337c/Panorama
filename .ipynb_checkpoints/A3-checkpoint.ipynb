# %% [markdown]
# # Part 1 A

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import scipy
from scipy.spatial import distance


# Provided code for plotting inlier matches between two images
def plot_inlier_matches(ax, img1, img2, inliers):
    """
    Plot the matches between two images according to the matched keypoints
    :param ax: plot handle
    :param img1: left image
    :param img2: right image
    :inliers: x,y in the first image and x,y in the second image (Nx4)
    """
    res = np.hstack([img1, img2])
    ax.set_aspect('equal')
    ax.imshow(res, cmap='gray')
    
    ax.plot(inliers[:,0], inliers[:,1], '+r')
    ax.plot(inliers[:,2] + img1.shape[1], inliers[:,3], '+r')
    ax.plot([inliers[:,0], inliers[:,2] + img1.shape[1]],
            [inliers[:,1], inliers[:,3]], 'r', linewidth=0.4)
    ax.axis('off')
    

# Preprocessing
img1 = cv.imread('parliament-left.jpg')
img2 = cv.imread('parliament-right.jpg')

img1_grey = cv.cvtColor(img1,cv.COLOR_BGR2GRAY)
img2_grey = cv.cvtColor(img2,cv.COLOR_BGR2GRAY)

# Detect keypoints and extract descriptors
sift = cv.SIFT_create()
kp_img1, des1 = sift.detectAndCompute(img1_grey,None)
kp_img2, des2 = sift.detectAndCompute(img2_grey,None)

# Matching by computing the squared Euclidean distance between every SIFT descriptor in img1 and descriptors from img2
eucli_dist = distance.cdist(des1, des2, 'sqeuclidean') # 2d matrix where rows are keypoints of img1 and cols are keypoints of img2

# Prune features based on top N smallest pairwise distance
N = 300 # Top 300 smallest pairwise distances
sorted_rows = np.argsort(eucli_dist.min(axis=1)) # Find smallest distances for each row, sort them, and store them by their indices
top_n_rows = sorted_rows[:N] 
best_match_indices = eucli_dist.argmin(axis=1) # Index list of best matches for each keypoint in img1
top_n_cols = best_match_indices[top_n_rows] # Retrieves corresponding img2 keypoints indices from top n keypoints in img1

# Display location of inliers matches in both images
img1_points_coord = np.array([kp_img1[i].pt for i in top_n_rows]) # [N,2] shape where it stores x,y position of each point 
img2_points_coord = np.array([kp_img2[i].pt for i in top_n_cols]) 

h1, w1 = img1_grey.shape
h2, w2 = img2_grey.shape

# Pad images to ensure height is the same for the inlier function
if h1 > h2:
    img2_padded = np.pad(img2_grey, ((0, h1 - h2), (0, 0)), mode='constant')
    img1_padded = img1_grey
else:
    img1_padded = np.pad(img1_grey, ((0, h2 - h1), (0, 0)), mode='constant')
    img2_padded = img2_grey

computed_inliers = np.hstack([img1_points_coord, img2_points_coord])

fig, ax = plt.subplots(figsize=(20,10))
plot_inlier_matches(ax, img1_padded, img2_padded, computed_inliers)
plt.show()

# Implement RANSAC to estimate an affine transformation that maps one image to the other
min_num_pairs = 3 # Minimum number of pairwise matches since we're solving for 6 unknowns in affine transformation

# Implement RANSAC loop to find the best iteration 
p = 0.2
n_iterations = 100
best_affine = None
inlier_best_count = 0
best_inlier_mask = None

for curr in range(n_iterations):
    # Choose 3 random samples from computed inliers and group all the first points together and all second points
    random_indices = np.random.choice(computed_inliers.shape[0], size=3, replace=False)
    sample = computed_inliers[random_indices]
    first_pts = sample[:, :2]
    second_pts = sample[:, 2:]
    
    # Solve for affine 6 unknown points using linear equations Ax = b
    b = np.zeros(6) # second points in a 6x1 vector
    A = np.zeros((2 * min_num_pairs,6))
    for i in range(min_num_pairs):
        x,y = first_pts[i]
        A[2 * i] = [x, y, 1, 0, 0, 0] # vector used to mutiple with unknown coefficients -> xa + yb + 1(c) = x'
        A[2 * i + 1] = [0, 0, 0, x, y, 1] # vector used to multiple with unknow coefficients -> xd + ye + f = y'
    
        # Fill in b
        x_2, y_2 = second_pts[i]
        b[2 * i] = x_2
        b[2 * i + 1] = y_2
        
    # Solve for x using x = A^-1 * b 
    try:
        x = np.linalg.solve(A, b)
    except np.linalg.LinAlgError: 
        # matrix A is not invertible due to all 3 points being collinear or we resampled two or more similar points
        print(f"Matrix A is not invertible, degenerate sample {A}")
        continue
    affine = x.reshape(2,3)
    
    # RANSAC Inlier counting
    ones = np.ones((img1_points_coord.shape[0], 1))
    homogeneous_img1_points = np.hstack([img1_points_coord, ones]) # Shape is now N x 3
    # Apply affine transformation to all keypoints in image 1 via dot product vectorization
    new_img1_points = affine @ homogeneous_img1_points.T # shape is now 2 x N
    # Calculate the distances between estimates keypoints and actual keypoints of image 2
    diff_coord = new_img1_points - img2_points_coord.T
    distances = np.linalg.norm(diff_coord, axis=0)
    inlier_mask = (distances < p)
    inlier_count = inlier_mask.sum()

    # Compare with best and update accordingly
    if inlier_count > inlier_best_count:
        inlier_best_count = inlier_count
        best_affine = affine
        best_inlier_mask = inlier_mask

print(f"Inliers: {inlier_best_count} / {N}")

# Compute optimal transformation 
A = np.zeros((2 * N, 6)) # A matrix for all inliers
# Get all inliers from image 1 and image 2 using the best model found
inliers_img1 = img1_points_coord[best_inlier_mask]
inliers_img2 = img2_points_coord[best_inlier_mask]



# Output images
# img_1 = cv.drawKeypoints(img1_grey,kp_img1,img1,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# plt.imshow(cv.cvtColor(img_1, cv.COLOR_BGR2RGB))
# plt.axis('off')
# plt.show()

# img_2 = cv.drawKeypoints(img2_grey,kp_img2,img2,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# plt.imshow(cv.cvtColor(img_2, cv.COLOR_BGR2RGB))
# plt.axis('off')
# plt.show()
# Out:
# Min distance: 0.0000
# Max distance: 1.3517
# Mean distance: 0.4722
# Min distance: 0.0000
# Max distance: 0.3115
# Mean distance: 0.1006
# Min distance: 0.0000
# Max distance: 0.4860
# Mean distance: 0.1642
# Min distance: 0.0000
# Max distance: 0.3586
# Mean distance: 0.1252
# Min distance: 0.0000
# Max distance: 0.3657
# Mean distance: 0.1442
# Min distance: 0.0000
# Max distance: 0.8927
# Mean distance: 0.3017
# Min distance: 0.0000
# Max distance: 0.5702
# Mean distance: 0.2023
# Min distance: 0.0000
# Max distance: 0.9164
# Mean distance: 0.3027
# Min distance: 0.0000
# Max distance: 20.1538
# Mean distance: 8.6405
# Min distance: 0.0000
# Max distance: 0.4366
# Mean distance: 0.1568
# Min distance: 0.0000
# Max distance: 0.3586
# Mean distance: 0.1383
# Min distance: 0.0000
# Max distance: 0.5704
# Mean distance: 0.1939
# Min distance: 0.0000
# Max distance: 0.7926
# Mean distance: 0.3080
# Min distance: 0.0000
# Max distance: 0.3221
# Mean distance: 0.0940
# Min distance: 0.0000
# Max distance: 0.4947
# Mean distance: 0.1488
# Min distance: 0.0000
# Max distance: 0.3502
# Mean distance: 0.1261
# Min distance: 0.0000
# Max distance: 0.4401
# Mean distance: 0.1418
# Min distance: 0.0000
# Max distance: 0.3241
# Mean distance: 0.1075
# Min distance: 0.0000
# Max distance: 34.6802
# Mean distance: 13.6734
# Min distance: 0.0000
# Max distance: 0.9743
# Mean distance: 0.3438
# Min distance: 0.0000
# Max distance: 0.4551
# Mean distance: 0.1957
# Min distance: 0.0000
# Max distance: 0.3498
# Mean distance: 0.1123
# Min distance: 0.0000
# Max distance: 0.3447
# Mean distance: 0.1113
# Min distance: 0.0000
# Max distance: 4.1528
# Mean distance: 1.7064
# Min distance: 0.0000
# Max distance: 0.4614
# Mean distance: 0.1505
# Min distance: 0.0000
# Max distance: 0.9003
# Mean distance: 0.2829
# Min distance: 0.0000
# Max distance: 0.3207
# Mean distance: 0.1211
# Min distance: 0.0000
# Max distance: 1.3909
# Mean distance: 0.6295
# Min distance: 0.0000
# Max distance: 0.2908
# Mean distance: 0.0972
# Min distance: 0.0000
# Max distance: 0.4889
# Mean distance: 0.1704
# Min distance: 0.0000
# Max distance: 1.6804
# Mean distance: 0.7932
# Min distance: 0.0000
# Max distance: 1.4696
# Mean distance: 0.6007
# Min distance: 0.0000
# Max distance: 0.9287
# Mean distance: 0.3531
# Min distance: 0.0000
# Max distance: 0.2914
# Mean distance: 0.0971
# Min distance: 0.0000
# Max distance: 0.4156
# Mean distance: 0.1458
# Min distance: 0.0000
# Max distance: 0.6878
# Mean distance: 0.2438
# Min distance: 0.0000
# Max distance: 3.1932
# Mean distance: 1.2272
# Min distance: 0.0000
# Max distance: 16.3216
# Mean distance: 6.1123
# Min distance: 0.0000
# Max distance: 0.3066
# Mean distance: 0.1018
# Min distance: 0.0000
# Max distance: 2.6400
# Mean distance: 0.8234
# Min distance: 0.0000
# Max distance: 0.3357
# Mean distance: 0.0861
# Min distance: 0.0000
# Max distance: 0.6145
# Mean distance: 0.2672
# Min distance: 0.0000
# Max distance: 0.3924
# Mean distance: 0.1412
# Min distance: 0.0000
# Max distance: 0.7319
# Mean distance: 0.2606
# Min distance: 0.0000
# Max distance: 0.3092
# Mean distance: 0.0967
# Min distance: 0.0000
# Max distance: 0.5281
# Mean distance: 0.1698
# Min distance: 0.0000
# Max distance: 0.9632
# Mean distance: 0.3513
# Min distance: 0.0000
# Max distance: 0.5687
# Mean distance: 0.2100
# Min distance: 0.0000
# Max distance: 0.3150
# Mean distance: 0.1076
# Min distance: 0.0000
# Max distance: 0.7361
# Mean distance: 0.2833
# Min distance: 0.0000
# Max distance: 0.4000
# Mean distance: 0.1781
# Min distance: 0.0000
# Max distance: 0.7277
# Mean distance: 0.2435
# Min distance: 0.0000
# Max distance: 0.4939
# Mean distance: 0.1671
# Min distance: 0.0000
# Max distance: 0.4171
# Mean distance: 0.1445
# Min distance: 0.0000
# Max distance: 0.8758
# Mean distance: 0.3682
# Min distance: 0.0000
# Max distance: 0.2679
# Mean distance: 0.0967
# Min distance: 0.0000
# Max distance: 0.5136
# Mean distance: 0.1869
# Min distance: 0.0000
# Max distance: 1.7919
# Mean distance: 0.6684
# Min distance: 0.0000
# Max distance: 4.6843
# Mean distance: 1.7769
# Min distance: 0.0000
# Max distance: 0.3149
# Mean distance: 0.1024
# Min distance: 0.0000
# Max distance: 0.3518
# Mean distance: 0.1333
# Min distance: 0.0000
# Max distance: 0.5631
# Mean distance: 0.1815
# Min distance: 0.0000
# Max distance: 2.6821
# Mean distance: 0.9996
# Min distance: 0.0000
# Max distance: 0.5505
# Mean distance: 0.1838
# Min distance: 0.0000
# Max distance: 0.4730
# Mean distance: 0.1660
# Min distance: 0.0000
# Max distance: 0.4348
# Mean distance: 0.1435
# Min distance: 0.0000
# Max distance: 0.2898
# Mean distance: 0.0935
# Min distance: 0.0000
# Max distance: 1.6311
# Mean distance: 0.6387
# Min distance: 0.0000
# Max distance: 0.4527
# Mean distance: 0.1730
# Min distance: 0.0000
# Max distance: 0.5396
# Mean distance: 0.2007
# Min distance: 0.0000
# Max distance: 0.6249
# Mean distance: 0.2659
# Min distance: 0.0000
# Max distance: 0.5622
# Mean distance: 0.2038
# Min distance: 0.0000
# Max distance: 166.9425
# Mean distance: 71.9702
# Min distance: 0.0000
# Max distance: 0.4127
# Mean distance: 0.1641
# Min distance: 0.0000
# Max distance: 0.3202
# Mean distance: 0.1031
# Min distance: 0.0000
# Max distance: 3.7184
# Mean distance: 1.4869
# Min distance: 0.0000
# Max distance: 59.0636
# Mean distance: 24.5270
# Min distance: 0.0000
# Max distance: 6.7589
# Mean distance: 2.4645
# Min distance: 0.0000
# Max distance: 1.2366
# Mean distance: 0.4350
# Min distance: 0.0000
# Max distance: 1.1713
# Mean distance: 0.4024
# Min distance: 0.0000
# Max distance: 0.3361
# Mean distance: 0.1089
# Min distance: 0.0000
# Max distance: 0.4746
# Mean distance: 0.1734
# Min distance: 0.0000
# Max distance: 2.0590
# Mean distance: 0.7722
# Min distance: 0.0000
# Max distance: 0.3621
# Mean distance: 0.1099
# Min distance: 0.0000
# Max distance: 0.5834
# Mean distance: 0.2105
# Min distance: 0.0000
# Max distance: 0.6425
# Mean distance: 0.2285
# Min distance: 0.0000
# Max distance: 0.3006
# Mean distance: 0.1069
# Min distance: 0.0000
# Max distance: 0.5837
# Mean distance: 0.2055
# Min distance: 0.0000
# Max distance: 0.5214
# Mean distance: 0.2176
# Min distance: 0.0000
# Max distance: 0.3724
# Mean distance: 0.1463
# Min distance: 0.0000
# Max distance: 0.2898
# Mean distance: 0.1050
# Min distance: 0.0000
# Max distance: 0.3013
# Mean distance: 0.1147
# Min distance: 0.0000
# Max distance: 1.1579
# Mean distance: 0.4998
# Min distance: 0.0000
# Max distance: 16.1785
# Mean distance: 6.2410
# Min distance: 0.0000
# Max distance: 0.3950
# Mean distance: 0.1557
# Min distance: 0.0000
# Max distance: 0.3126
# Mean distance: 0.1096
# Min distance: 0.0000
# Max distance: 0.4123
# Mean distance: 0.1303
# Min distance: 0.0000
# Max distance: 0.3657
# Mean distance: 0.1471
# Min distance: 0.0000
# Max distance: 1.7914
# Mean distance: 0.6610
# Min distance: 0.0000
# Max distance: 0.5081
# Mean distance: 0.1918
# Inliers: 290 / 300

# %% [markdown]
# # Part 1 B
